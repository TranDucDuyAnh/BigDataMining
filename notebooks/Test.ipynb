# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("test") \
    .getOrCreate()

print(spark.version)
spark.createDataFrame([("hello", 1), ("pyspark", 2)], ["word", "num"]).show()
# Out:
# 3.5.0
# +-------+---+
# |   word|num|
# +-------+---+
# |  hello|  1|
# |pyspark|  2|
# +-------+---+
